# %% [markdown]
# <h1><span style="color:green;font-weight:bold;">Curso de Python do Zero ao Data Engineer</span></h1>
#
# <h3><span style="color:orange; font-weight:bold;">Aula 01 - Começando com Python</span></h3>
#
# <h3><span style="color:orange;">Agenda:</span></h3>
# <ul>
#     <li><span style="color:black;">1.0. Problema de negócio.</span></li>
#     <li><span style="color:black;">2.0. Planejamento de solução.</span></li>
#     <li><span style="color:black;">3.0. O que é Python?</span></li>
#     <li><span style="color:black;">4.0. Como escrever código Python.</span></li>
#     <li><span style="color:black;">5.0. Os primeiros comandos Python.</span></li>
#     <li><span style="color:black;">6.0. Responder as questões Python.</span></li>
#     <li><span style="color:black;">7.0. Exercícios.</span></li>
# </ul>

# %% [markdown]
# <h4><span style="color:orange;">1.0. Problema de negócio.</span></h4>
# <a href="https://medium.com/@meigarom/os-5-projetos-de-data-science-que-far%C3%A1-o-recrutador-olhar-para-voc%C3%AA-c32c67c17cc9" target="_blank">Link do Artigo</a>
#
# <ul>
#     <li><span style="color:green;">Empresa:
#         <ul>
#             <li><span style="color:black;">House Rocket</span></li>
#         </ul>
#     </span></li>
#     <li><span style="color:green;">O que a empresa faz:
#         <ul>
#             <li><span style="color:black;">House Rocket plataforma de compras e vendas de imóveis</span></li>
#         </ul>
#     </span></li>
#     <li><span style="color:green;">Qual o problema?
#         <ul>
#             <li><span style="color:black;">O CEO da empresa gostaria de maximizar o lucro da empresa encontrando bons negócios</span></li>
#         </ul>
#     </span></li>
#     <li><span style="color:green;">A principal estratégia?
#         <ul>
#             <li><span style="color:black;">Fontes externas para encontrar bons negócios</span></li>
#         </ul>
#     </span></li>
#     <li><span style="color:green;">As perguntas do CEO da House Rocket:
#         <ol>
#             <li><span style="color:black;">Quantas casas estão disponíveis para compra?</span></li>
#             <li><span style="color:black;">Quantos atributos as casas possuem? (nº de quartos, nº de garagens, m², vistas pro mar)</span></li>
#             <li><span style="color:black;">Quais são os atributos?</span></li>
#             <li><span style="color:black;">Qual a casa mais cara do portfólio (casa com maior valor)?</span></li>
#             <li><span style="color:black;">Qual a casa com maior nº de quartos?</span></li>
#         </ol>
#     </span></li>
# </ul>

# %% [markdown]
# <h4><span style="color:orange;">2.0. Planejamento de solução.</span></h4>
# <ul>
#     <ul>
#         <li><span style="color:green;">2.1. Planejamento do Produto Final:</span>
#             <ol>
#                 <li><span style="color:black;">O que eu vou entregar? (Planilha, Texto, Email, Modelos de ML, ...)</span>
#                     <ul>
#                         <li><span style="color:black;">R: Texto com as respostas.</span></li>
#                     </ul>
#                 </li>
#                 <li><span style="color:black;">Como vai ser a entrega?</span>
#                     <ul>
#                         <li><span style="color:black;">R: Perguntas | Respostas.</span>
#                         <br><span style="color:black;">Por exemplo:</span>
#                             <ol>
#                                 <li><span style="color:black;">Quantas casas estão disponíveis para compra?</span></li>
#                                 <lo><span style="color:black;">R: 2300 imóveis disponíveis para compra.</lo>
#                                 <li><span style="color:black;">Quantos atributos as casas possuem? (nº de quartos, nº de garagens, m², vistas pro mar)</span></li>
#                                 <lo><span style="color:black;">R: 10 atributos.</lo>
#                                 <li><span style="color:black;">Quais são os atributos?</span></li>
#                                 <li><span style="color:black;">Qual a casa mais cara do portfólio (casa com maior valor)?</span></li>
#                                 <li><span style="color:black;">Qual a casa com maior nº de quartos?</span></li>
#                             </ol>
#                         </li>
#                     </ul>
#                 </li>
#             </ol>
#         </li>
#         <li><span style="color:green;">2.2. Planejamento do Processo.</span>
#             <ol>
#                 <li><span style="color:black;">Onde está a informação? (Excel, BD, API, Manual)</span></li>
#                 <li><span style="color:black;">Como coletar essas informações? (SQL, Python, Streamilt, ...)</span></li>
#                 <li><span style="color:black;">Responder as perguntas?</span></li>
#             </ol>
#         </li>
#         <li><span style="color:green;">2.3. Planejamento das Ferramentas.</span>
#             <ol>
#                 <li><span style="color:black;">O CEO da empresa gostaria de maximizar o lucro da empresa encontrando bons negócios</span></li>
#             </ol>
#         </li>
#     </ul>
# </ul>
